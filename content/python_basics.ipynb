# %% [markdown]
# # Python Basics
# Welcome! Let's cover variables, loops, and functions — the building blocks of everything else you'll learn.

# %%
# Variables
name = 'Aditi'
age = 21
is_student = True

print(name, age, is_student)

# %% [markdown]
# ## Loops
# Try changing the range below and re-run the cell.

# %%
for i in range(1, 6):
    print(f'Step {i}: learning Python!')

# %% [markdown]
# ## Functions

# %%
def greet(student_name):
    return f'Welcome to CodEdge Academy, {student_name}!'

print(greet('Rahul'))
print(greet('Priya'))

# %% [markdown]
# ## Your turn
# Write a function that takes a list of numbers and returns the largest one.

# %%
def find_max(numbers):
    # write your code here
    pass

print(find_max([4, 9, 2, 7, 15, 3]))
